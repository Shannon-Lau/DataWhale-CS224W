# %%
import networkx as nx
# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %% [markdown]
# # 无向全连接图

# %%
# 绘制无向全脸截图，节点设置为5
G = nx.complete_graph(5)

# %%
# 绘制图像
nx.draw(G)

# %%
# 图的连接数
G.size()
# Out:
# 10

# %% [markdown]
# # 有向全连接图

# %%
# 设置有向全连接图
G = nx.complete_graph(5, nx.DiGraph())

# %%
# 绘制
nx.draw(G)

# %%
# 连接个数
G.size()
# Out:
# 20

# %%
# 图像是否为有向图
G.is_directed()
# Out:
# True

# %% [markdown]
# # 环状图

# %%
# 无向环状图
G = nx.cycle_graph(5)
nx.draw(G)

# %%
# 有向环状图
G = nx.cycle_graph(5, nx.DiGraph())
nx.draw(G)

# %% [markdown]
# # 梯状图

# %%
G = nx.ladder_graph(5)
nx.draw(G)

# %%
# 不支持有向图
G = nx.ladder_graph(5, nx.DiGraph())
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 G = nx.ladder_graph(5, nx.DiGraph())
#       2 nx.draw(G)
#
# File D:\Anaconda3\envs\GNN\lib\site-packages\networkx\generators\classic.py:509, in ladder_graph(n, create_using)
#     507 G = empty_graph(2 * n, create_using)
#     508 if G.is_directed():
# --> 509     raise NetworkXError("Directed Graph not supported")
#     510 G.add_edges_from(pairwise(range(n)))
#     511 G.add_edges_from(pairwise(range(n, 2 * n)))
#
# NetworkXError: Directed Graph not supported

# %% [markdown]
# # 线性串珠图

# %%
# 无向线性串珠图
G = nx.path_graph(15)
nx.draw(G)

# %%
# 有向线性串珠图
G = nx.path_graph(15, nx.DiGraph())
nx.draw(G)

# %% [markdown]
# # 星状图

# %%
# 无向星状图
G = nx.star_graph(7)
nx.draw(G)

# %%
# 不支持有向图
G = nx.star_graph(7, nx.DiGraph())
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 有向星状图
# ----> 2 G = nx.star_graph(7, nx.DiGraph())
#       3 nx.draw(G)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 20:4, in argmap_star_graph_17(n, create_using)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File D:\Anaconda3\envs\GNN\lib\site-packages\networkx\generators\classic.py:624, in star_graph(n, create_using)
#     622 G = empty_graph(nodes, create_using)
#     623 if G.is_directed():
# --> 624     raise NetworkXError("Directed Graph not supported")
#     626 if len(nodes) > 1:
#     627     hub, *spokes = nodes
#
# NetworkXError: Directed Graph not supported

# %%
# 轮辐图
G = nx.wheel_graph(7)
nx.draw((G))

# %%
# 不支持有向图
G = nx.wheel_graph(7, nx.DiGraph())
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 不支持有向图
# ----> 2 G = nx.wheel_graph(7, nx.DiGraph())
#       3 nx.draw(G)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 24:4, in argmap_wheel_graph_21(n, create_using)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File D:\Anaconda3\envs\GNN\lib\site-packages\networkx\generators\classic.py:690, in wheel_graph(n, create_using)
#     688 G = empty_graph(nodes, create_using)
#     689 if G.is_directed():
# --> 690     raise NetworkXError("Directed Graph not supported")
#     692 if len(nodes) > 1:
#     693     hub, *rim = nodes
#
# NetworkXError: Directed Graph not supported

# %% [markdown]
# # 二项树

# %%
# 无向二项树
G = nx.binomial_tree(5)
nx.draw(G)

# %%
# 有向二项树
G = nx.binomial_tree(5,nx.DiGraph())
nx.draw(G)

# %% [markdown]
# # 二维矩形网状树

# %%
G = nx.grid_2d_graph(3,5)
nx.draw(G)

# %% [markdown]
# # 多维矩形网状图

# %%
G = nx.grid_graph(dim=(2,3,4))
nx.draw(G)

# %% [markdown]
# # 二维三角形网状图

# %%
G = nx.triangular_lattice_graph(2,5)
nx.draw(G)

# %% [markdown]
# # 二维六边形蜂窝图

# %%
G = nx.hexagonal_lattice_graph(2,3)
nx.draw(G)

# %% [markdown]
# # N维超立方体图

# %%
G = nx.hypercube_graph(4)
nx.draw(G)

# %% [markdown]
# # 钻石图

# %%
G = nx.diamond_graph()
nx.draw(G)

# %% [markdown]
# # Bull_Graph

# %% [markdown]
# # 牛角图

# %%
# 无向牛角图
G = nx.bull_graph()
nx.draw(G)

# %%
# 有向牛角图
G = nx.bull_graph(nx.DiGraph())
nx.draw(G)

# %% [markdown]
# # frucht图

# %%
G = nx.frucht_graph()
nx.draw(G)

# %% [markdown]
# # House图

# %%
# 无向图
G = nx.house_graph()
nx.draw(G)

# %%
# 有向图
G = nx.house_graph(nx.DiGraph())
nx.draw(G)

# %% [markdown]
# # House X 图

# %%
G = nx.house_x_graph()
nx.draw(G)

# %%
G = nx.house_x_graph(nx.DiGraph())
nx.draw(G)

# %% [markdown]
# # 彼得森图petersen

# %%
# 无向
G = nx.petersen_graph()
nx.draw(G)

# %%
# 有向
G = nx.petersen_graph(nx.DiGraph())
nx.draw(G)

# %% [markdown]
# # 风筝图

# %%
# 有向
G = nx.krackhardt_kite_graph(nx.DiGraph())
nx.draw(G)

# %%
# 无向
G = nx.krackhardt_kite_graph()
nx.draw(G)

# %% [markdown]
# # 随即图

# %%
G = nx.erdos_renyi_graph(10, 0.5)
nx.draw(G)

# %% [markdown]
# # 无标度有向图

# %%
G = nx.scale_free_graph(20)
nx.draw(G)

# %% [markdown]
# # 空手道数据集

# %%
# 空手道俱乐部
G = nx.karate_club_graph()
nx.draw(G, with_labels=True)

# %% [markdown]
# 空手道俱乐部数据集堪称图机器学习中的鸢尾花数据集，什么算法都可以在他上面进行效果测试。<br>
# 所有会员被分成了不同的派系。

# %%
# 第五个节点的所属派系
G.nodes[5]['club']
# Out:
# 'Mr. Hi'

# %%
# 第九个节点的所属派系
G.nodes[9]['club']
# Out:
# 'Officer'

# %% [markdown]
# # 雨果——悲惨世界

# %%
# 雨果《悲惨世界》人物关系
G = nx.les_miserables_graph()
plt.figure(figsize=(12,10))
pos = nx.spring_layout(G, seed=10) # 设置一个弹簧布局，随机数种子为10
nx.draw(G, pos, with_labels=True)

# %% [markdown]
# # 家族系谱图

# %%
# Florentine families graph
G = nx.florentine_families_graph()
nx.draw(G, with_labels=True)

# %% [markdown]
# # 社群聚类图

# %%
G = nx.caveman_graph(4, 3)
nx.draw(G, with_labels=True)

# %% [markdown]
# # 树状结构

# %%
tree = nx.random_tree(n=10, seed=0)
print(nx.forest_str(tree, sources=[0]))
# Out:
# ╙── 0
#     ├── 3
#     └── 4
#         ├── 6
#         │   ├── 1
#         │   ├── 2
#         │   └── 7
#         │       └── 8
#         │           └── 5
#         └── 9
